# %% [markdown]
# Esse notebook fará uma analise estatísticas da NBA. Tentarei deixar tudo de forma mais clara possível para que seja fácil replicar e melhorá-lo.
#
# Bom, esse notebook será estruturado de tal forma:
# 1. Web Scrapping dos dados
# 2. Tratamento dos dados
# 3. Visualização dos dados
#
# Esses dados serão baixados do site [basketball-reference](https://www.basketball-reference.com/), onde pegaremos dados entre 1950 e 2020. Não considerarei a temporada atual (2020-2021) pois a mesma ainda está em andamento, porém se você utilizar esse notebook após a temporada 2020-2021, atualize os dados para ter uma melhor visualização da realidade, pois estou fazendo esse notebook em maio de 2021. Esse notebook tem a intenção de analisar os números das temporadas gerais e individuais de forma que possamos descobrir tendências para a NBA e comparar com o passado para analisar mudanças.

# %% [markdown]
# Primeiro importaremos as bibliotecas utilizadas nesse notebook.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Criaremos uma função para baixar os dados do site [basketball-reference](https://www.basketball-reference.com/) e salvar os dados em nossa máquina, de forma há não precisarmos rodar essa célula sempre e quando precisarmos baixar novos dados, podemos apenas baixar os dados referente ao ano que quisermos.

# %%
def web_scrapping_nba(base_url, ano_inicio, ano_fim):
    anos = range(ano_inicio, ano_fim + 1, 1)
    
    for ano in anos:
        req_url = base_url.format(ano)
        req = requests.get(req_url)
        soup = BeautifulSoup(req.content, 'html.parser')
        table = soup.find('table', {'id': 'totals_stats'})
        df = pd.read_html(str(table))[0]
        # criando uma coluna com os anos
        df['Year'] = ano
        df.to_csv(f'./dados/nba_{ano}.csv')

# %% [markdown]
# Usando a função para baixar os dados.

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_{}_totals.html'

dados = web_scrapping_nba(url, 1950, 2020)

# %% [markdown]
# Bom, após criar a função que baixa e salva os arquivos em nossa máquina, devemos importar esses arquivos para podermos usá-los. Criaremos uma função para isso.

# %%
def nba_carregamento(ano_inicio, ano_fim):
    anos = range(ano_inicio, ano_fim + 1, 1)
    dados_finais = pd.DataFrame()

    for ano in anos:
        dados = pd.read_csv(f'./dados/nba_{ano}.csv')
        dados_finais = dados_finais.append(dados)
    return dados_finais

# %%
dados = nba_carregamento(1950, 2020)
dados
# Out:
#      Unnamed: 0   Rk           Player  Pos Age   Tm   G   GS    MP   FG  ...  \
# 0             0    1  Curly Armstrong  G-F  31  FTW  63  NaN   NaN  144  ...
# 1             1    2     Cliff Barker   SG  29  INO  49  NaN   NaN  102  ...
# 2             2    3    Leo Barnhorst   SF  25  CHS  67  NaN   NaN  174  ...
# 3             3    4       Ed Bartels    F  24  TOT  15  NaN   NaN   22  ...
# 4             4    4       Ed Bartels    F  24  DNN  13  NaN   NaN   21  ...
# ..          ...  ...              ...  ...  ..  ...  ..  ...   ...  ...  ...
# 672         672  525       Trae Young   PG  21  ATL  60   60  2120  546  ...
# 673         673  526      Cody Zeller    C  27  CHO  58   39  1341  251  ...
# 674         674  527     Tyler Zeller    C  30  SAS   2    0     4    1  ...
# 675         675  528       Ante Žižić    C  23  CLE  22    0   221   41  ...
# 676         676  529      Ivica Zubac    C  22  LAC  72   70  1326  236  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0    NaN  NaN  NaN  176  NaN  NaN  NaN  217   458  1950
# 1    NaN  NaN  NaN  109  NaN  NaN  NaN   99   279  1950
# 2    NaN  NaN  NaN  140  NaN  NaN  NaN  192   438  1950
# 3    NaN  NaN  NaN   20  NaN  NaN  NaN   29    63  1950
# 4    NaN  NaN  NaN   20  NaN  NaN  NaN   27    59  1950
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 672   32  223  255  560   65    8  289  104  1778  2020
# 673  160  251  411   88   40   25   75  140   642  2020
# 674    3    1    4    0    0    0    0    0     2  2020
# 675   18   48   66    6    7    5   10   27    96  2020
# 676  197  346  543   82   16   66   61  168   596  2020
#
# [27778 rows x 32 columns]

# %% [markdown]
# Temos uma coluna `Rk` que é uma forma de índice do site. Vamos colocar essa coluna no índice.

# %%
dados.index = dados['Rk']
dados
# Out:
#      Unnamed: 0   Rk           Player  Pos Age   Tm   G   GS    MP   FG  ...  \
# Rk                                                                       ...
# 1             0    1  Curly Armstrong  G-F  31  FTW  63  NaN   NaN  144  ...
# 2             1    2     Cliff Barker   SG  29  INO  49  NaN   NaN  102  ...
# 3             2    3    Leo Barnhorst   SF  25  CHS  67  NaN   NaN  174  ...
# 4             3    4       Ed Bartels    F  24  TOT  15  NaN   NaN   22  ...
# 4             4    4       Ed Bartels    F  24  DNN  13  NaN   NaN   21  ...
# ..          ...  ...              ...  ...  ..  ...  ..  ...   ...  ...  ...
# 525         672  525       Trae Young   PG  21  ATL  60   60  2120  546  ...
# 526         673  526      Cody Zeller    C  27  CHO  58   39  1341  251  ...
# 527         674  527     Tyler Zeller    C  30  SAS   2    0     4    1  ...
# 528         675  528       Ante Žižić    C  23  CLE  22    0   221   41  ...
# 529         676  529      Ivica Zubac    C  22  LAC  72   70  1326  236  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# Rk
# 1    NaN  NaN  NaN  176  NaN  NaN  NaN  217   458  1950
# 2    NaN  NaN  NaN  109  NaN  NaN  NaN   99   279  1950
# 3    NaN  NaN  NaN  140  NaN  NaN  NaN  192   438  1950
# 4    NaN  NaN  NaN   20  NaN  NaN  NaN   29    63  1950
# 4    NaN  NaN  NaN   20  NaN  NaN  NaN   27    59  1950
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 525   32  223  255  560   65    8  289  104  1778  2020
# 526  160  251  411   88   40   25   75  140   642  2020
# 527    3    1    4    0    0    0    0    0     2  2020
# 528   18   48   66    6    7    5   10   27    96  2020
# 529  197  346  543   82   16   66   61  168   596  2020
#
# [27778 rows x 32 columns]

# %% [markdown]
# Vendo os csv's, vemos que há valores de `Rk` dentro da coluna Rk. Vamos excluir esses valores.

# %%
drop_indexes = dados[dados.index == 'Rk'].index
dados.drop(drop_indexes, inplace=True)

# %%
dados
# Out:
#      Unnamed: 0   Rk           Player  Pos Age   Tm   G   GS    MP   FG  ...  \
# Rk                                                                       ...
# 1             0    1  Curly Armstrong  G-F  31  FTW  63  NaN   NaN  144  ...
# 2             1    2     Cliff Barker   SG  29  INO  49  NaN   NaN  102  ...
# 3             2    3    Leo Barnhorst   SF  25  CHS  67  NaN   NaN  174  ...
# 4             3    4       Ed Bartels    F  24  TOT  15  NaN   NaN   22  ...
# 4             4    4       Ed Bartels    F  24  DNN  13  NaN   NaN   21  ...
# ..          ...  ...              ...  ...  ..  ...  ..  ...   ...  ...  ...
# 525         672  525       Trae Young   PG  21  ATL  60   60  2120  546  ...
# 526         673  526      Cody Zeller    C  27  CHO  58   39  1341  251  ...
# 527         674  527     Tyler Zeller    C  30  SAS   2    0     4    1  ...
# 528         675  528       Ante Žižić    C  23  CLE  22    0   221   41  ...
# 529         676  529      Ivica Zubac    C  22  LAC  72   70  1326  236  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# Rk
# 1    NaN  NaN  NaN  176  NaN  NaN  NaN  217   458  1950
# 2    NaN  NaN  NaN  109  NaN  NaN  NaN   99   279  1950
# 3    NaN  NaN  NaN  140  NaN  NaN  NaN  192   438  1950
# 4    NaN  NaN  NaN   20  NaN  NaN  NaN   29    63  1950
# 4    NaN  NaN  NaN   20  NaN  NaN  NaN   27    59  1950
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 525   32  223  255  560   65    8  289  104  1778  2020
# 526  160  251  411   88   40   25   75  140   642  2020
# 527    3    1    4    0    0    0    0    0     2  2020
# 528   18   48   66    6    7    5   10   27    96  2020
# 529  197  346  543   82   16   66   61  168   596  2020
#
# [26722 rows x 32 columns]

# %% [markdown]
# Vamos remover as colunas `Unamed: 0` e `Rk`

# %%
dados = dados.drop(['Unnamed: 0', 'Rk'], axis=1)
dados
# Out:
#               Player  Pos Age   Tm   G   GS    MP   FG   FGA   FG%  ...  ORB  \
# Rk                                                                  ...
# 1    Curly Armstrong  G-F  31  FTW  63  NaN   NaN  144   516  .279  ...  NaN
# 2       Cliff Barker   SG  29  INO  49  NaN   NaN  102   274  .372  ...  NaN
# 3      Leo Barnhorst   SF  25  CHS  67  NaN   NaN  174   499  .349  ...  NaN
# 4         Ed Bartels    F  24  TOT  15  NaN   NaN   22    86  .256  ...  NaN
# 4         Ed Bartels    F  24  DNN  13  NaN   NaN   21    82  .256  ...  NaN
# ..               ...  ...  ..  ...  ..  ...   ...  ...   ...   ...  ...  ...
# 525       Trae Young   PG  21  ATL  60   60  2120  546  1249  .437  ...   32
# 526      Cody Zeller    C  27  CHO  58   39  1341  251   479  .524  ...  160
# 527     Tyler Zeller    C  30  SAS   2    0     4    1     4  .250  ...    3
# 528       Ante Žižić    C  23  CLE  22    0   221   41    72  .569  ...   18
# 529      Ivica Zubac    C  22  LAC  72   70  1326  236   385  .613  ...  197
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# Rk
# 1    NaN  NaN  176  NaN  NaN  NaN  217   458  1950
# 2    NaN  NaN  109  NaN  NaN  NaN   99   279  1950
# 3    NaN  NaN  140  NaN  NaN  NaN  192   438  1950
# 4    NaN  NaN   20  NaN  NaN  NaN   29    63  1950
# 4    NaN  NaN   20  NaN  NaN  NaN   27    59  1950
# ..   ...  ...  ...  ...  ...  ...  ...   ...   ...
# 525  223  255  560   65    8  289  104  1778  2020
# 526  251  411   88   40   25   75  140   642  2020
# 527    1    4    0    0    0    0    0     2  2020
# 528   48   66    6    7    5   10   27    96  2020
# 529  346  543   82   16   66   61  168   596  2020
#
# [26722 rows x 30 columns]

# %% [markdown]
# Vamos ver que tipos de dados que há em nossos dados.

# %%
dados.dtypes
# Out:
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# Year       int64
# dtype: object

# %% [markdown]
# Bom, vemos que todos os dados, tirando a única coluna criada por nós anteriormente (a coluna `Year`), são todos do tipo `object`. Vamos transforma todos os dados que são números em números.

# %%
# excluindo colunas que não são númericas
colunas_numericas = dados.columns.drop(['Player','Pos','Tm'])
dados[colunas_numericas] = dados[colunas_numericas].apply(pd.to_numeric)

# %% [markdown]
# Pronto, agora todos nossos dados estão da forma certa. Veremos como estão agora.

# %%
dados.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G         float64
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Year        int64
# dtype: object

# %% [markdown]
# Vamos então dar uma olhada em nossos dados, agrupando pelos jogadores.

# %%
jogadores = dados.groupby('Player', as_index=False).sum()
maiores_pontuadores = jogadores.sort_values(by=['PTS'], axis=0, ascending=False)
maiores_pontuadores.head()
# Out:
#                     Player  Age       G      GS       MP       FG      FGA  \
# 2379  Kareem Abdul-Jabbar*  630  1560.0   625.0  57446.0  15837.0  28307.0
# 2381          Karl Malone*  589  1476.0  1471.0  54852.0  13528.0  26210.0
# 2619          LeBron James  459  1265.0  1264.0  48551.0  12481.0  24781.0
# 4215     Wilt Chamberlain*  469  1118.0     0.0  51160.0  13744.0  25580.0
# 2522          Kobe Bryant*  550  1346.0  1198.0  48637.0  11719.0  26200.0
#
#          FG%      3P     3PA  ...     ORB      DRB      TRB     AST     STL  \
# 2379  11.167     1.0    18.0  ...  2975.0   9394.0  17440.0  5660.0  1160.0
# 2381   9.745    85.0   310.0  ...  3562.0  11406.0  14968.0  5248.0  2085.0
# 2619   8.595  1875.0  5453.0  ...  1509.0   7896.0   9405.0  9346.0  2015.0
# 4215   8.955     0.0     0.0  ...     0.0      0.0  25597.0  4893.0     0.0
# 2522   8.828  1827.0  5546.0  ...  1499.0   5548.0   7047.0  6306.0  1944.0
#
#          BLK     TOV      PF      PTS   Year
# 2379  3189.0  2527.0  4657.0  38387.0  39590
# 2381  1145.0  4524.0  4578.0  36928.0  37905
# 2619   957.0  4424.0  2325.0  34241.0  34204
# 4215     0.0     0.0  2221.0  33953.0  31461
# 2522   640.0  4010.0  3353.0  33643.0  40130
#
# [5 rows x 28 columns]

# %% [markdown]
# Temos muitos dados. Vamos ver quantas colunas possuem nossos dados

# %%
dados.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year'],
#       dtype='object')

# %% [markdown]
# Bom, já temos uma base de como nossos dados são e fizemos um breve tratamento. Agora vamos começar a analisá-los.

# %% [markdown]
# ## Criando funções de plot
#
# Para facilitar nosso trabalho, criaremos funções para plotar ao gráficos que repetiremos, de modo que não tenhamos que escrever o mesmo código várias vezes.

# %% [markdown]
# ### Função gráfico duas imagens
#
# Esse gráfico tem como principal função plotar gráficos das temporadas, pois como estamos falando de dados de 1950 até 2020, um plot só não daria conta.
#
# Vamos a função.

# %%
def grafico_duas_imagens(dados, legenda_x=None, legenda_y=None, titulo=None,
                         legenda_linha_media=None, legenda_barras=None,
                         cor='C0'):
    
    # cria a figura
    fig = plt.figure(figsize=(14, 12))
    
    # cria os eixos
    ax1 = fig.add_subplot(2, 1, 1)
    ax2 = fig.add_subplot(2, 1, 2)
    
    # estilo do gráfico
    plt.style.use('seaborn')
    
    # gráfico do primeiro eixo
    dados[:35].plot(kind='bar', ax=ax1, xlabel=legenda_x, ylabel=legenda_y,
                    title=titulo, color=cor, label=legenda_barras)
    ax1.axhline(dados.mean(), color='red', label=legenda_linha_media)
    
    
    # gráfico do segundo eixo
    dados[35:].plot(kind='bar', ax=ax2, xlabel=legenda_x, ylabel=legenda_y,
                    color=cor, label=legenda_barras)
    ax2.axhline(dados.mean(), color='red', label=legenda_linha_media)
   
    # forçar legenda
    ax1.legend()
    ax2.legend()
    
    # plotar o gráfico
    plt.show()

# %% [markdown]
# ### Função gráfico individual
#
# Essa função tem como objetivo principal plotar gráficos para analise individual dos jogadores, pois teremos como parâmetro analisar apenas os dez maiores jogadores de cada fundamento.

# %%
def plot_grafico_barras(eixo_x, eixo_y, x_label='Jogadores', y_label='', titulo='',
                        fonte_legenda=14, casas_decimais=2, cor_legenda_interna='black'):
    
    # cria a figura
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7), constrained_layout=True)
    
    # estilo do gráfico
    plt.style.use('seaborn')
    
    # gráfico
    sns.barplot(x=eixo_x.head(10), y=eixo_y.head(10))
    
    # legendas eixos
    ax.set_xlabel(x_label, fontsize=fonte_legenda)
    
    ax.set_ylabel(y_label, fontsize=fonte_legenda)
    plt.xticks(rotation=45)
    
    # titulo
    ax.set_title(titulo, fontsize=16)
    
    # condicional para plotar linha de média apenas em gráficos percentuais
    if casas_decimais != 0:
        media = ((eixo_y.head(100).sum()) / 100)
        ax.axhline(media, color='red', label='Média dos 100 primeiros')
    
    # colocar valores dentro dos gráficos
    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        ax.text(x=x_value, y= 0.2 * y_value , s=f'{y_value:.{casas_decimais}f}',
                ha='center', va='bottom', rotation=0, color=cor_legenda_interna
                , weight='bold')
    
    # colocar legenda
    ax.legend()
    
    # plotar o gráfico
    plt.show()

# %% [markdown]
# ## Função gráfico de regressão
#
# Essa função tem como objetivo plotar linhas de regressão para os dados, para analisarmos tendências, vendo se há uma expectativa de crescimento ou não e tentando entender esses resultados.

# %%
def grafico_regressao(eixo_x, eixo_y, x_label='Ano', y_label='',
                        fonte_legenda=14, cor=None):
    
    # estilo do gráfico
    plt.style.use('seaborn')
    
    # cria a figura
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7), constrained_layout=True)
    
    # gráfico
    sns.regplot(x=eixo_x, y=eixo_y, scatter=False, color=cor)
    
    # legendas eixos
    ax.set_xlabel(x_label, fontsize=fonte_legenda)
    
    ax.set_ylabel(y_label, fontsize=fonte_legenda)
    
    
    # plotar o gráfico
    plt.show()

# %% [markdown]
# Bom, as funções já estão criadas, vamos aos gráficos.

# %% [markdown]
# # Temporadas
#
# Começaremos pelos gráficos das temporadas.
#
# Vamos analisar os seguintes pontos.
# 1. Número de jogos médios por jogadores
# 2. Pontos por temporada médios por jogador
# 3. Pontos por temporada feitos de cestas de 3 pontos médios por jogador
# 4. Número de assistências médios por jogador
# 5. Número de bloqueios médios por jogador
# 6. Número de roubos de bola médios por jogador
# 7. Número de rebotes por jogador

# %% [markdown]
# ## Jogos

# %% [markdown]
# Vamos comparar o número de jogos por média dos jogadores da NBA. No ano de 1950 haviam 68 jogos por time na temporada regular. Hoje (2021) o número é de 82 jogos por temporada, porém vale ressaltar que na temporada de 2020 houve menos jogos, 72 jogos, devido a pandemia de Covid-19.

# %%
jogos = dados.groupby('Year')['G'].mean()

# %%
grafico_duas_imagens(jogos, legenda_x='Ano', legenda_y='Jogos',
                     legenda_linha_media='Média dos jogos por jogador em todos os anos',
                     titulo='Média de jogos por jogador entre 1950 e 2020',
                     legenda_barras='Média dos jogos no ano',
                     cor='C0')

# %% [markdown]
# Com os gráficos acima conseguimos ver que há uma tendência a diminuir o número de jogos nos últimos anos na NBA. Nos últimos 13 anos há uma média de jogos por jogador menor do que os valor médio desses últimos 70 anos.
#
# Podemos também ver que em 1999 foi o ano com a menor média. Isso se deve ao ano de 1999 ter tido apenas 56 jogos por equipe. O motivo desse baixo número de jogos foi ao segundo grande bloqueio da história da NBA, que durou de 1º de julho de 1998 a 20 de janeiro de 1999.
#
# Vamos analisar agora, para confirmarmos nossas suspeitas um gráfico de regressão.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['G'], y_label='Jogos', cor='C0')

# %% [markdown]
# Comprovamos que houve uma queda na média de jogos por jogadores nesses anos. Um dos principais motivos podem ser o rodizios feito por times da NBA. Hoje há um plantel de jogadores maior, o que disponibiliza uma maior rotatividade entre os jogadores. Lógico que grandes estrelas continuam tendo um número elevado de jogos, mas o maior número de jogadores leva a esse decrescimento nos últimos anos.

# %% [markdown]
# ## Pontos por temporada

# %% [markdown]
# Veremos agora a média de pontos por jogador.

# %%
pontos_media_jogadores = dados.groupby('Year')['PTS'].mean()

# %%
grafico_duas_imagens(pontos_media_jogadores, legenda_x='Ano',legenda_y='Número de pontos',
                     legenda_barras='Pontos por jogador em média por temporada',
                     legenda_linha_media='Média dos pontos por jogador por temporada',
                     titulo='Número de pontos feito pelos cestinhas da NBA,por\
 temporada, no período de 1950 a 2020', cor='C5')

# %% [markdown]
# Os gráficos nos mostram que há uma tendẽncia há diminuição de pontos nos últimos anos. Por mais elásticos que os placares sejam hoje em dia, muitas vezes passando dos 120 pontos por time em um jogo, há um aumento no plantel da equipe e no número de jogos, o que faz com que  tenha essa diluição na média de pontos por jogador. Vamos confimar isso com uma regressão.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['PTS'], y_label='Média de pontos',
                  cor='C5')

# %% [markdown]
# ## 3 Pontos

# %%
dados_3_pontos = dados.groupby('Year')['3P'].mean() 

grafico_duas_imagens(dados_3_pontos, legenda_x='Ano', legenda_y='Pontos',
                     legenda_linha_media='Média de 3 pontos em todos os anos',
                     titulo='Média de 3 pontos por ano entre 1950 e 2020',
                     legenda_barras='Média de 3 pontos por ano',
                     cor='C1')

# %% [markdown]
# A cesta de 3 pontos foi adotada pela NBA na temporada 79/80.
#
# O primeiro time a explorar os tiros de 3 pontos foi o New York Knicks, na temporada 88/89, porém nos anos 80 e 90 o jogo no garrafão, com grandes pivos, como Pat Ewing, Shaquille O'Neal, Hakeem Olajuwon, ainda era uma das principais forças das equipes.
#
# A grande virada das cestas de 3 pontos foi a partir dos anos 2000, com o grande uso por Ray Allen, e posteriormente, nos anos 2010 entrou em seu auge, se tornando hoje uma das principais armas ofensivas do jogo, introduzida especialmente pelo armador do Golden State Warrior, Stephen Curry.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['3P'],
                  y_label='Média de cestas de 3 pontos', cor='C1')

# %% [markdown]
# Com o gráfico acima, confirmamos nossas hipóteses anteriores.

# %% [markdown]
# ## Assistências

# %%
dados_assistencia = dados.groupby('Year')['AST'].mean() 

grafico_duas_imagens(dados_assistencia, legenda_x='Ano', legenda_y='Assitências',
                     legenda_linha_media='Média de assistências em todos os anos',
                     titulo='Média de assistências por ano entre 1950 e 2020',
                     legenda_barras='Média de assistências por ano',
                     cor='C15')

# %% [markdown]
# Ao longo dos anos a média de assitências por jogador diminuiu. Hoje, os jogadores da posição 1, armadores, não tem apenas a função de armar o jogo, como também tem a função de atacar a cesta, sendo muitas vezes esses jogadores as principais armas ofensivas de seus times ou pelo menos o principal jogador ofensivo do time.
#
# Essa grande tendência começou a ser mais utilizada no final dos anos 90 e ínicio dos anos 2000, onde alguns times, exemplo do 76ers, lideradores pelo armador Allen Iverson, apostavam suas fichas em armadores que eram extramamente agressivos no ataque, que lideravam o time no ataque ao invés de ficar apenas armando as jogadas. Exemplos de hoje são Stephen Curry, James Harden, Russel Westbrook, entre outros.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['AST'], y_label='Assistência',
                  cor='C15')

# %% [markdown]
# Bom, agora vamos agrupar esses dados em gráficos mostrando cada década da NBA e vendo a evolução do jogo nesses períodos.

# %%
ataque_serie = [dados_assistencia, pontos_media_jogadores, dados_3_pontos]

# %%
ataque_df = pd.DataFrame(ataque_serie).transpose()
ataque_df
# Out:
#              AST         PTS         3P
# Year
# 1950   81.717949  331.929487        NaN
# 1951   90.486772  366.693122        NaN
# 1952  114.664179  434.801471        NaN
# 1953  103.493827  401.716049        NaN
# 1954  106.237037  415.940741        NaN
# ...          ...         ...        ...
# 2016  102.384083  465.636678  38.970588
# 2017  101.060504  474.732773  43.932773
# 2018   93.182229  428.143072  42.266566
# 2019   96.324859  441.285311  46.121469
# 2020   85.774194  396.477727  43.798771
#
# [71 rows x 3 columns]

# %% [markdown]
# Mudando o nome das colunas

# %%
ataque_df.columns = ['Média de assitências', 'Média de pontos', 'Média de 3 pontos']

# %% [markdown]
# Vamos criar também um dataframe apenas com assitências e média de pontos

# %%
assistencia_e_pontos = [dados_assistencia, pontos_media_jogadores]
assistencia_e_pontos_df = pd.DataFrame(assistencia_e_pontos).transpose()
assistencia_e_pontos_df.columns = ['Média de assitências', 'Média de pontos']

# %%
# criando figura 1
fig = plt.figure(figsize=(14, 12))

# criando figura 2
fig2 = plt.figure(figsize=(14, 12))

# criando figura 3
fig3 = plt.figure(figsize=(14, 12))

# criando figura 4
fig4 = plt.figure(figsize=(14, 12))

# criando eixos
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax3 = fig2.add_subplot(2, 1, 1)
ax4 = fig2.add_subplot(2, 1, 2)
ax5 = fig3.add_subplot(2, 1, 1)
ax6 = fig3.add_subplot(2, 1, 2)
ax7 = fig4.add_subplot(2, 1, 1)

assistencia_e_pontos_df.iloc[0:10].plot(ax=ax1 ,kind='bar', figsize=(14, 10), width=0.3)
assistencia_e_pontos_df.iloc[10:20].plot(ax=ax2 ,kind='bar', figsize=(14, 10), width=0.3)
assistencia_e_pontos_df.iloc[20:30].plot(ax=ax3 ,kind='bar', figsize=(14, 10), width=0.3)
ataque_df.iloc[30:40].plot(ax=ax4 ,kind='bar', figsize=(14, 10))
ataque_df.iloc[40:50].plot(ax=ax5 ,kind='bar', figsize=(14, 10))
ataque_df.iloc[50:60].plot(ax=ax6 ,kind='bar', figsize=(14, 10))
ataque_df.iloc[60:71].plot(ax=ax7 ,kind='bar', figsize=(14, 10))

# colocando todos os gráficos com os mesmo limites
ax1.set_ylim(0,800)
ax2.set_ylim(0,800)
ax3.set_ylim(0,800)
ax4.set_ylim(0,800)
ax5.set_ylim(0,800)
ax6.set_ylim(0,800)
ax7.set_ylim(0,800)

# titulo
ax1.set_title('Evolução de fundamentos ofensivos na NBA por década de 1950 a 2020', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Evolução de fundamentos ofensivos na NBA por década de 1950 a 2020')

# %% [markdown]
# Bom, vimos os principais quesitos ofensivos por temporada. Agora veremos os principais quesitos defensivos.

# %% [markdown]
# ## Bloqueio

# %%
dados_bloqueio = dados.groupby('Year')['BLK'].mean() 

grafico_duas_imagens(dados_bloqueio, legenda_x='Ano', legenda_y='Bloqueios',
                     legenda_linha_media='Média de bloqueios em todos os anos',
                     titulo='Média de bloqueios por ano entre 1950 e 2020',
                     legenda_barras='Média de bloqueios por ano',
                     cor='C10')

# %% [markdown]
# O número de bloqueios começou a ser computado na temporada 73/74. Vemos que houve uma queda na média de bloqueios por jogador no últimos anos. Isso se deve ao fato de o jogo ter mudado bastante, hoje, o estilo do jogo é um jogo mais no perímetro, espaçando os jogadores na linha de 3 pontos e tentando ou uma bola de três ou uma infiltração. Antigamente havia uma maior valorização do jogo dentro do garrafão.
#
# O estilo de jogo no garrafão faz com que haja maiores probabilidades de ocorrer um bloqueio em comparação com um jogo espeçado objetivando uma bola de 3 pontos. Vamos confirmar nossa hipótese com uma regressão.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['BLK'], y_label='Bloqueio', cor='C10')

# %% [markdown]
# ## Roubos de bola

# %%
dados_steal = dados.groupby('Year')['STL'].mean() 

grafico_duas_imagens(dados_steal, legenda_x='Ano', legenda_y='Roubos de bola',
                     legenda_linha_media='Média de roubos de bola em todos os anos',
                     titulo='Média de roubos de bola por ano entre 1950 e 2020',
                     legenda_barras='Média de roubos de bola por ano',
                     cor='C20')

# %% [markdown]
# Outra tendência com queda na NBA. A queda dos roubos de bola se deve ao mesmo motivo dos bloqueios, já que o estilo atual de jogo possibilita menos roubos de bola, por ter um espaçamento maior na quadra, enquanto antigamente com o jogo mais dentro do garrafão, possibilitava uma maior taxa de roubo de bola.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['STL'], y_label='Roubo de bola',
                  cor='C20')

# %% [markdown]
# ## Rebotes

# %%
dados_rebotes = dados.groupby('Year')['TRB'].mean() 

grafico_duas_imagens(dados_steal, legenda_x='Ano', legenda_y='Rebotes',
                     legenda_linha_media='Média de rebotes em todos os anos',
                     titulo='Média de rebotes por ano entre 1950 e 2020',
                     legenda_barras='Média de rebotes por ano',
                     cor='orange')

# %% [markdown]
# Há uma queda, porém isso não se deve ao fato de pegarem menos rebotes hoje em dia, e sim ao maior número de jogadores por elenco. Como há um maior número de jogadores, maior será o número de jogadores que irão participar da média, fazendo com que a média seja menor.

# %%
grafico_regressao(eixo_x=dados['Year'], eixo_y=dados['TRB'], y_label='Rebotes',
                  cor='orange')

# %% [markdown]
# Da mesma forma que fizemos com os fundamentos ofensivos, vamos aqui agora ver os principais fundamentos defensivos agrupados por década.

# %%
defesa_serie = [dados_bloqueio, dados_rebotes, dados_steal]

# %%
defesa_df = pd.DataFrame(defesa_serie).transpose()
defesa_df
# Out:
#             BLK         TRB        STL
# Year
# 1950        NaN         NaN        NaN
# 1951        NaN  207.508571        NaN
# 1952        NaN  254.871212        NaN
# 1953        NaN  228.062500        NaN
# 1954        NaN  249.061069        NaN
# ...         ...         ...        ...
# 2016  22.133218  197.588235  35.728374
# 2017  21.478992  196.312605  34.653782
# 2018  19.010542  174.284639  31.146084
# 2019  19.290960  180.122881  30.577684
# 2020  17.658986  160.314900  27.517665
#
# [71 rows x 3 columns]

# %%
defesa_df.columns = ['Média de bloqueios', 'Média de rebotes', 'Média de roubos de bola']

# %%
# criando figura 1
fig = plt.figure(figsize=(14, 12))

# criando figura 2
fig2 = plt.figure(figsize=(14, 12))

# criando figura 3
fig3 = plt.figure(figsize=(14, 12))

# criando figura 4
fig4 = plt.figure(figsize=(14, 12))

# criando eixos
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax3 = fig2.add_subplot(2, 1, 1)
ax4 = fig2.add_subplot(2, 1, 2)
ax5 = fig3.add_subplot(2, 1, 1)
ax6 = fig3.add_subplot(2, 1, 2)
ax7 = fig4.add_subplot(2, 1, 1)

defesa_serie = [dados_bloqueio, dados_rebotes, dados_steal] 

dados_rebotes.iloc[0:10].plot(ax=ax1 ,kind='bar', figsize=(14, 10),
                              color='C1', label='Média de rebotes', width=0.15)
dados_rebotes.iloc[10:20].plot(ax=ax2 ,kind='bar', figsize=(14, 10), color='C1', 
                               label='Média de rebotes', width=0.15)
defesa_df.iloc[20:30].plot(ax=ax3 ,kind='bar', figsize=(14, 10))
defesa_df.iloc[30:40].plot(ax=ax4 ,kind='bar', figsize=(14, 10))
defesa_df.iloc[40:50].plot(ax=ax5 ,kind='bar', figsize=(14, 10))
defesa_df.iloc[50:60].plot(ax=ax6 ,kind='bar', figsize=(14, 10))
defesa_df.iloc[60:71].plot(ax=ax7 ,kind='bar', figsize=(14, 10))

# colocando todos os gráficos com os mesmo limites
ax1.set_ylim(0,450)
ax2.set_ylim(0,450)
ax3.set_ylim(0,450)
ax4.set_ylim(0,450)
ax5.set_ylim(0,450)
ax6.set_ylim(0,450)
ax7.set_ylim(0,450)

# titulo
ax1.set_title('Evolução de fundamentos defensivos na NBA por década de 1950 a 2020', fontsize=16)

# forçar legendas
ax1.legend()
ax2.legend()

# %% [markdown]
# ## Conclusão para temporadas
# Vendo todos os dados das temporadas podemos concluir algumas coisas:
# 1. Há uma maior tendência ao jogo ofensivo, principalmente com bolas de 3 nos dias atuais quando comparados com décadas anteriores
# 2. Defensivamente, pelos dados, a NBA era mais forte, pois era muito comum os times terem defesas muito sólidas, com grandes defensores como Hakeem Olajuwon ou Dennis Rodman. E a tendência do jogo ser mais dentro do garrafão, fazia com que houvesse um jogo de mais contato, que salientava a grande importância da defesa.
# 3. Há uma tendência a queda de pontos por jogador na NBA. O esporte hoje ele tem um quesito coletivo maior, fazendo com que a participação de jogadores que não tem uma grande representação ofensiva aconteça com maior frequência. Além disso há um maior número de jogadores por elenco, 15 atualmente, fazendo com que a divisão de pontos seja por todos os jogadores.

# %% [markdown]
# Bom, visto tudo acima, onde conseguimos analisar as temporadas, vamos agora ver por jogadores.

# %% [markdown]
# # Jogadores

# %% [markdown]
# Primeiro, vamos ver os 10 maiores pontuadores da história.

# %%
dados_pontuacao = dados[['Player','PTS', '2P', '2PA', '3P', '3PA','FT',
                           'FTA', 'AST', 'STL', 'BLK', 'TRB', 'ORB', 'DRB']]
jogadores = dados_pontuacao.groupby('Player', as_index=False).sum()
maiores_pontuadores = jogadores.sort_values(by=['PTS'], axis=0, ascending=False)
maiores_pontuadores.head(10)
# Out:
#                     Player      PTS       2P      2PA      3P     3PA      FT  \
# 2379  Kareem Abdul-Jabbar*  38387.0  15836.0  28289.0     1.0    18.0  6712.0
# 2381          Karl Malone*  36928.0  13443.0  25900.0    85.0   310.0  9787.0
# 2619          LeBron James  34241.0  10606.0  19328.0  1875.0  5453.0  7404.0
# 4215     Wilt Chamberlain*  33953.0  13744.0  25580.0     0.0     0.0  6465.0
# 2522          Kobe Bryant*  33643.0   9892.0  20654.0  1827.0  5546.0  8378.0
# 2931       Michael Jordan*  32292.0  11611.0  22759.0   581.0  1778.0  7327.0
# 1323         Eddie Johnson  31852.0  11946.0  24568.0   783.0  2334.0  5611.0
# 1163         Dirk Nowitzki  31560.0   9187.0  18524.0  1982.0  5210.0  7240.0
# 3685     Shaquille O'Neal*  29428.0  11660.0  19993.0     1.0    22.0  6105.0
# 4095          Vince Carter  28636.0   7845.0  16969.0  2533.0  6802.0  5347.0
#
#           FTA     AST     STL     BLK      TRB     ORB      DRB
# 2379   9304.0  5660.0  1160.0  3189.0  17440.0  2975.0   9394.0
# 2381  13188.0  5248.0  2085.0  1145.0  14968.0  3562.0  11406.0
# 2619  10082.0  9346.0  2015.0   957.0   9405.0  1509.0   7896.0
# 4215  12742.0  4893.0     0.0     0.0  25597.0     0.0      0.0
# 2522  10011.0  6306.0  1944.0   640.0   7047.0  1499.0   5548.0
# 2931   8772.0  5633.0  2514.0   893.0   6672.0  1668.0   5004.0
# 1323   6836.0  6482.0  1591.0   282.0   6884.0  2420.0   4464.0
# 1163   8239.0  3651.0  1210.0  1281.0  11489.0  1468.0  10021.0
# 3685  11590.0  3119.0   771.0  2820.0  13653.0  4375.0   9278.0
# 4095   6715.0  5187.0  1706.0   956.0   7282.0  1818.0   5464.0

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores['Player'],
                    eixo_y=maiores_pontuadores['PTS'],
                    y_label='Número de pontos',titulo='Maiores pontuadores de todos os tempos',
                    casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Como anteriormente, vamos focar primeiro no ataque e depois na defesa

# %% [markdown]
# # Ataque
#
#
# No ataque, nós analisaremos.
#
# 1. Maiores pontuadores de 3 pontos.
# 2. Eficiência desses maiores pontuadores de 3 pontos.
# 3. Maiores pontuadores de 2 pontos.
# 4. Eficiência desses maiores pontuadores de 2 pontos.
# 5. Maiores pontuadores de lances livres.
# 6. Eficiência desses maiores pontuadores de lances livres.
# 7. Maiores assistentes
#
# Para uma melhor visualização, vamos considerar como maiores apenas os 10 primeiros colocados de cada quesito.
#
# Nos quesitos de eficiência, consideramos as eficiências dos maiores pontuadores apenas, pois há possivelmente jogadores mais eficientes, porém com número de pontuação mais baixo, o que faz com que seja difícil a comparação.

# %% [markdown]
# ## 3 pontos
#
# Começaremos pela maior tendência da NBA atual: a bola de 3 pontos. Levamos em consideração nesse critério a quantidade de cestas de 3 pontos feitas.

# %%
maiores_pontuadores_3pt = jogadores.sort_values(by=['3P'], axis=0, ascending=False)
maiores_pontuadores_3pt.head(10)
# Out:
#                 Player  Age       G      GS       MP       FG      FGA  \
# 3358        Ray Allen*  585  1376.0  1224.0  49224.0   9165.0  20318.0
# 2544       Kyle Korver  706  1444.0   445.0  36002.0   4798.0  10850.0
# 3397    Reggie Miller*  549  1389.0  1304.0  47619.0   8241.0  17499.0
# 4095      Vince Carter  839  1691.0  1122.0  51246.0  10378.0  23771.0
# 3760     Stephen Curry  286   699.0   693.0  23998.0   5682.0  11931.0
# 1854    Jamal Crawford  646  1392.0   498.0  41473.0   7171.0  17489.0
# 1873      James Harden  275   833.0   620.0  28589.0   6171.0  13925.0
# 1937       Jason Terry  589  1410.0   679.0  42034.0   6914.0  15585.0
# 672   Chauncey Billups  667  1274.0  1158.0  40323.0   5767.0  13936.0
# 2149       Joe Johnson  656  1489.0  1236.0  50058.0   8596.0  19522.0
#
#          FG%      3P     3PA  ...     ORB     DRB     TRB     AST     STL  \
# 3358   9.024  3174.0  7962.0  ...  1324.0  4329.0  5653.0  4695.0  1554.0
# 2544  10.172  2861.0  6718.0  ...   382.0  3781.0  4163.0  2406.0   905.0
# 3397   8.427  2560.0  6486.0  ...   883.0  3299.0  4182.0  4141.0  1505.0
# 4095  11.088  2533.0  6802.0  ...  1818.0  5464.0  7282.0  5187.0  1706.0
# 3760   5.182  2495.0  5739.0  ...   490.0  2668.0  3158.0  4621.0  1205.0
# 1854   9.132  2363.0  6773.0  ...   489.0  2652.0  3141.0  4829.0  1236.0
# 1873   4.878  2324.0  6394.0  ...   652.0  3794.0  4446.0  5255.0  1314.0
# 1937   8.265  2282.0  6010.0  ...   502.0  2772.0  3274.0  5415.0  1603.0
# 672    9.158  2245.0  5810.0  ...   599.0  3012.0  3611.0  6843.0  1322.0
# 2149  10.043  2176.0  5919.0  ...  1205.0  4575.0  5780.0  5581.0  1209.0
#
#         BLK     TOV      PF      PTS   Year
# 3358  258.0  2907.0  3078.0  26218.0  40105
# 2544  465.0  1493.0  2927.0  13971.0  46292
# 3397  299.0  2409.0  2730.0  25279.0  35937
# 4095  956.0  2848.0  4431.0  28636.0  52241
# 3760  156.0  2179.0  1732.0  16419.0  22165
# 1854  284.0  2624.0  2100.0  20699.0  44228
# 1873  443.0  3078.0  2204.0  20962.0  22165
# 1937  275.0  2415.0  2577.0  18881.0  38171
# 672   204.0  2666.0  2648.0  19303.0  46138
# 2149  291.0  2730.0  2579.0  22350.0  46242
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_3pt['Player'],
                    eixo_y=maiores_pontuadores_3pt['3P'],
                    y_label='Cestas de 3 pontos',titulo='Maiores pontuadores de 3 pontos',
                    casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Ray Allen, um grande ala-armador dos anos 2000, bicampeão da NBA é o principal pontuador de 3 pontos da história atualmente. Possivelmente deve ser passado por Stephen Curry no futuro.

# %% [markdown]
# ## Eficiência 3 pontos
#
# Aqui, consideramos a quantidade de cestas feitas divido pela quantidade tentada.

# %%
maiores_pontuadores_3pt['3P%'] = (maiores_pontuadores_3pt['3P'] / maiores_pontuadores_3pt['3PA'])

# %%
media_eficiencia_3pt = (maiores_pontuadores_3pt['3P%'].head(100).sum() / 100)
media_eficiencia_3pt
# Out:
# 0.37120361388990636

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_3pt['Player'],
                    eixo_y=maiores_pontuadores_3pt['3P%'],
                    titulo='Jogadores mais eficientes de 3 pontos',
                    y_label='Eficiência de 3 pontos')

# %% [markdown]
# Vemos que Stephen Curry é hoje o chutador mais eficiente de 3 pontos da história. Muitos já o consideram o melhor arremessador da história da NBA. Com seus arremos certeiros foi capaz de levar o Golden State Warriors a 3 aneis de campeão na última década e é até hoje o único MVP unânime da história da NBA.

# %% [markdown]
# ## 2 pontos
#
# Jogadores que mais acertaram cestas de 2 pontos.

# %%
maiores_pontuadores_2pt = jogadores.sort_values(by=['2P'], axis=0, ascending=False)

# %%
maiores_pontuadores_2pt.head(10)
# Out:
#                     Player  Age       G      GS       MP       FG      FGA  \
# 2379  Kareem Abdul-Jabbar*  630  1560.0   625.0  57446.0  15837.0  28307.0
# 4215     Wilt Chamberlain*  469  1118.0     0.0  51160.0  13744.0  25580.0
# 2381          Karl Malone*  589  1476.0  1471.0  54852.0  13528.0  26210.0
# 1323         Eddie Johnson  975  2078.0   749.0  57054.0  12729.0  26902.0
# 3685     Shaquille O'Neal*  621  1268.0  1258.0  43666.0  11661.0  20015.0
# 2931       Michael Jordan*  432  1072.0  1039.0  41011.0  12192.0  24537.0
# 79           Alex English*  502  1271.0   753.0  40464.0  11212.0  22149.0
# 1358          Elvin Hayes*  488  1303.0   129.0  50000.0  10976.0  24272.0
# 1655      Hakeem Olajuwon*  549  1238.0  1186.0  44222.0  10749.0  20991.0
# 2619          LeBron James  459  1265.0  1264.0  48551.0  12481.0  24781.0
#
#          FG%      3P     3PA  ...     ORB      DRB      TRB     AST     STL  \
# 2379  11.167     1.0    18.0  ...  2975.0   9394.0  17440.0  5660.0  1160.0
# 4215   8.955     0.0     0.0  ...     0.0      0.0  25597.0  4893.0     0.0
# 2381   9.745    85.0   310.0  ...  3562.0  11406.0  14968.0  5248.0  2085.0
# 1323  15.376   783.0  2334.0  ...  2420.0   4464.0   6884.0  6482.0  1591.0
# 3685  12.336     1.0    22.0  ...  4375.0   9278.0  13653.0  3119.0   771.0
# 2931   7.324   581.0  1778.0  ...  1668.0   5004.0   6672.0  5633.0  2514.0
# 79     8.547    20.0    89.0  ...  3047.0   4096.0   7143.0  4575.0  1140.0
# 1358   7.239     5.0    34.0  ...  2778.0   6973.0  16279.0  2398.0   864.0
# 1655   9.120    25.0   124.0  ...  4034.0   9714.0  13748.0  3058.0  2162.0
# 2619   8.595  1875.0  5453.0  ...  1509.0   7896.0   9405.0  9346.0  2015.0
#
#          BLK     TOV      PF      PTS   Year
# 2379  3189.0  2527.0  4657.0  38387.0  39590
# 4215     0.0     0.0  2221.0  33953.0  31461
# 2381  1145.0  4524.0  4578.0  36928.0  37905
# 1323   282.0  4112.0  5058.0  31852.0  65607
# 3685  2820.0  3491.0  4374.0  29428.0  42054
# 2931   893.0  2924.0  2783.0  32292.0  29892
# 79     895.0  3035.0  3233.0  26931.0  33720
# 1358  1771.0  1358.0  4193.0  27313.0  31624
# 1655  3830.0  3667.0  4383.0  26946.0  35883
# 2619   957.0  4424.0  2325.0  34241.0  34204
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_2pt['Player'],
                    eixo_y=maiores_pontuadores_2pt['2P'],
                    y_label='Cestas de 2 pontos',
                    titulo='Maiores pontuadores de 2 pontos',
                    casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Kareem Abdul-Jabbar leva esse quesito. Um dos maiores jogadores de todos os tempos, sendo colocado por muitos no top 3 de todos os tempos, sendo 6 vezes campeão da NBA e 6 vezes MVP da temporada regular, Kareem é uma lenda do basquete.

# %% [markdown]
# ## Eficiências 2 pontos
#
# Aqui levaremos em conta as cestas feitas divididas pelas tentativas de cestas de 2 pontos{

# %%
maiores_pontuadores_2pt['2P%'] = (maiores_pontuadores_2pt['2P'] / maiores_pontuadores_2pt['2PA'])

# %%
media_2pt = (maiores_pontuadores_2pt['2P%'].head(100).sum() / 100)

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_2pt['Player'],
                    eixo_y=maiores_pontuadores_2pt['2P%'],
                    titulo='Jogadores mais eficientes de 2 pontos',
                    y_label='Eficiência de 2 pontos')

# %% [markdown]
# Shaquille O'Neal, o pivô mais gente boa da história da NBA e considerado por muitos como o mais dominante também, era uma força da natureza embaixo do garrafão. 4 vezes campeão NBA e top 10 maiores jogadores de todos os tempos, Shaq possuia um jogo imparável dentro do garrafão, o que faz com que sua eficiência seja maior que a dos outros.

# %% [markdown]
# ## Lances livres

# %% [markdown]
# Veremos aqui os jogadores que mais acertaram lances livres.

# %%
maiores_pontuadores_lv = jogadores.sort_values(by=['FT'], axis=0, ascending=False)

# %%
maiores_pontuadores_lv.head(10)
# Out:
#                 Player  Age       G      GS       MP       FG      FGA    FG%  \
# 2381      Karl Malone*  589  1476.0  1471.0  54852.0  13528.0  26210.0  9.745
# 3057     Moses Malone*  612  1411.0   784.0  47577.0   9824.0  20035.0  9.428
# 2522      Kobe Bryant*  550  1346.0  1198.0  48637.0  11719.0  26200.0  8.828
# 34     Adrian Dantley*  530  1107.0   613.0  39506.0   9217.0  17203.0  9.879
# 3169  Oscar Robertson*  399  1040.0     0.0  43886.0   9508.0  19620.0  6.757
# 2619      LeBron James  459  1265.0  1264.0  48551.0  12481.0  24781.0  8.595
# 2931   Michael Jordan*  432  1072.0  1039.0  41011.0  12192.0  24537.0  7.324
# 1163     Dirk Nowitzki  630  1522.0  1460.0  51368.0  11169.0  23734.0  9.723
# 101     Allen Iverson*  581  1064.0  1042.0  43303.0   9532.0  22369.0  8.674
# 2043       Jerry West*  399   932.0     0.0  36571.0   9016.0  19032.0  6.622
#
#           3P     3PA  ...     ORB      DRB      TRB     AST     STL     BLK  \
# 2381    85.0   310.0  ...  3562.0  11406.0  14968.0  5248.0  2085.0  1145.0
# 3057     8.0    80.0  ...  7168.0  10116.0  17284.0  1885.0  1156.0  1914.0
# 2522  1827.0  5546.0  ...  1499.0   5548.0   7047.0  6306.0  1944.0   640.0
# 34       7.0    42.0  ...  2589.0   3803.0   6392.0  3254.0  1105.0   187.0
# 3169     0.0     0.0  ...    71.0    208.0   7804.0  9887.0    77.0     4.0
# 2619  1875.0  5453.0  ...  1509.0   7896.0   9405.0  9346.0  2015.0   957.0
# 2931   581.0  1778.0  ...  1668.0   5004.0   6672.0  5633.0  2514.0   893.0
# 1163  1982.0  5210.0  ...  1468.0  10021.0  11489.0  3651.0  1210.0  1281.0
# 101   1158.0  3704.0  ...   814.0   3025.0   3839.0  6488.0  2213.0   185.0
# 2043     0.0     0.0  ...    30.0     86.0   5366.0  6238.0    81.0    23.0
#
#          TOV      PF      PTS   Year
# 2381  4524.0  4578.0  36928.0  37905
# 3057  3804.0  3351.0  28492.0  41688
# 2522  4010.0  3353.0  33643.0  40130
# 34    2894.0  2969.0  26274.0  37694
# 3169     0.0  2931.0  26710.0  27545
# 2619  4424.0  2325.0  34241.0  34204
# 2931  2924.0  2783.0  32292.0  29892
# 1163  2494.0  3601.0  31560.0  42189
# 101   3740.0  2006.0  27457.0  40101
# 2043     0.0  2435.0  25192.0  27545
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_lv['Player'],
                    eixo_y=maiores_pontuadores_lv['FT'],
                    titulo='Maiores pontuadores de lances livres',
                    y_label='Cestas de Lances Livres', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Karl Malone, principal jogador o Utah Jazz dos anos 90, um ala de força, duas vezes MVP da temporada regular, sendo um dos maiores jogadores da história. Pelo seu jogo de força absurdo, sofria muitas faltas, o que fez ele ir várias vezes a linha de lances livres.

# %% [markdown]
# ## Eficiência lances livres

# %%
maiores_pontuadores_lv['FT%'] = (maiores_pontuadores_lv['FT'] / maiores_pontuadores_2pt['FTA'])

# %%
media_lv = (maiores_pontuadores_lv['FT%'].head(100).sum() / 100)

# %%
plot_grafico_barras(eixo_x=maiores_pontuadores_lv['Player'],
                    eixo_y=maiores_pontuadores_lv['FT%'],
                    titulo='Jogadores mais eficientes de lances livres',
                    y_label='Eficiência de Lances Livres')

# %% [markdown]
# Aqui cabe um disclaimer. Esses não são os mais eficientes chutadores de lances livres da NBA. Stephen Curry é o melhor atualmente. Porém, esse gráfico é baseado em quem é o melhor dos 10 maiores pontuadores de lances livres. Como dito anteriormente, haverá jogadores mais eficientes do que os mostrados nos quesitos, porém esse projeto tem o objetivo de avaliar a eficiência dos dez maiores pontuadores de cada fundamento na atualidade.
#
# O alemão Dirk Nowitzki, uma vez MVP da temporada regular e uma vez campeão da NBA é o jogador mais eficiente na linha de lance livre da história.

# %% [markdown]
# ## Assistência

# %%
maiores_jogadores_assistentes = jogadores.sort_values(by=['AST'], axis=0, ascending=False)

# %%
maiores_jogadores_assistentes.head(10)
# Out:
#                 Player  Age       G      GS       MP       FG      FGA  \
# 2239    John Stockton*  589  1504.0  1300.0  47764.0   7039.0  13658.0
# 1930       Jason Kidd*  684  1526.0  1475.0  54981.0   6737.0  16879.0
# 2799      Mark Jackson  642  1461.0  1256.0  44763.0   5326.0  11993.0
# 3793       Steve Nash*  549  1217.0  1053.0  38069.0   6321.0  12892.0
# 2730    Magic Johnson*  342   906.0   763.0  33245.0   6211.0  11951.0
# 3169  Oscar Robertson*  399  1040.0     0.0  43886.0   9508.0  19620.0
# 135       Andre Miller  815  1562.0  1024.0  45930.0   6769.0  14640.0
# 721         Chris Paul  405  1020.0  1020.0  35558.0   6596.0  14019.0
# 1508      Gary Payton*  578  1415.0  1313.0  50325.0   9373.0  20164.0
# 2619      LeBron James  459  1265.0  1264.0  48551.0  12481.0  24781.0
#
#          FG%      3P     3PA  ...     ORB     DRB     TRB      AST     STL  \
# 2239   9.737   845.0  2203.0  ...   966.0  3085.0  4051.0  15806.0  3265.0
# 1930   9.150  2168.0  6178.0  ...  1926.0  7648.0  9574.0  13393.0  2944.0
# 2799   9.126   870.0  2598.0  ...  1435.0  4228.0  5663.0  11930.0  1789.0
# 3793   8.591  1685.0  3939.0  ...   643.0  2999.0  3642.0  10335.0   899.0
# 2730   6.745   325.0  1074.0  ...  1601.0  4958.0  6559.0  10141.0  1724.0
# 3169   6.757     0.0     0.0  ...    71.0   208.0  7804.0   9887.0    77.0
# 135   11.882   218.0   986.0  ...  1547.0  3934.0  5481.0   9717.0  1738.0
# 721    7.031  1379.0  3730.0  ...   667.0  3944.0  4611.0   9653.0  2233.0
# 1508   8.746  1186.0  3752.0  ...  1471.0  4132.0  5603.0   9629.0  2578.0
# 2619   8.595  1875.0  5453.0  ...  1509.0  7896.0  9405.0   9346.0  2015.0
#
#         BLK     TOV      PF      PTS   Year
# 2239  315.0  4244.0  3942.0  19711.0  37886
# 1930  496.0  4411.0  2851.0  18992.0  46086
# 2799  136.0  3604.0  2530.0  13932.0  41928
# 3793  102.0  3478.0  1982.0  17387.0  36099
# 2730  374.0  3506.0  2050.0  17707.0  25822
# 3169    4.0     0.0  2931.0  26710.0  27545
# 135   252.0  3545.0  3290.0  18135.0  50240
# 721   133.0  2465.0  2500.0  18829.0  30195
# 1508  305.0  3217.0  3398.0  23447.0  37989
# 2619  957.0  4424.0  2325.0  34241.0  34204
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_jogadores_assistentes['Player'],
                    eixo_y=maiores_jogadores_assistentes['AST'],
                    titulo='Maiores jogadores assistentes da história',
                    y_label='Assistências', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# John Stockton, grande armador do Utah Jazz dos anos 90, fez uma das melhores duplas da época junto com seu companheiro Karl Malone.

# %% [markdown]
# # Defesa
#
# Na defesa, nós analisaremos.
#
# 1. Maiores reboteiros ofensivos.
# 2. Maiores reboteiros defensivos.
# 3. Maiores reboteiros totais.
# 4. Maiores bloqueadores.
# 5. Maiores roubadores de bola.

# %% [markdown]
# ## Rebotes ofensivos

# %%
maiores_reboteiros_ofensivos = jogadores.sort_values(by=['ORB'], axis=0, ascending=False)
maiores_reboteiros_ofensivos.head(10)
# Out:
#                  Player  Age       G      GS       MP       FG      FGA  \
# 3057      Moses Malone*  612  1411.0   784.0  47577.0   9824.0  20035.0
# 2502       Kevin Willis  896  1644.0  1036.0  44717.0   8197.0  16989.0
# 3470     Robert Parish*  693  1611.0  1134.0  45704.0   9614.0  17914.0
# 547       Buck Williams  493  1307.0  1140.0  42464.0   6404.0  11661.0
# 3685  Shaquille O'Neal*  621  1268.0  1258.0  43666.0  11661.0  20015.0
# 1064     Dennis Rodman*  441   911.0   573.0  28839.0   2766.0   5310.0
# 639    Charles Barkley*  456  1073.0  1012.0  39330.0   8435.0  15605.0
# 1155   Dikembe Mutombo*  671  1271.0  1072.0  39382.0   4438.0   8601.0
# 1655   Hakeem Olajuwon*  549  1238.0  1186.0  44222.0  10749.0  20991.0
# 649      Charles Oakley  589  1282.0  1159.0  40280.0   4835.0  10263.0
#
#          FG%     3P     3PA  ...     ORB      DRB      TRB     AST     STL  \
# 3057   9.428    8.0    80.0  ...  7168.0  10116.0  17284.0  1885.0  1156.0
# 2502  12.550   45.0   220.0  ...  4744.0   9059.0  13803.0  1517.0  1107.0
# 3470  11.124    0.0     6.0  ...  4598.0  10117.0  14715.0  2180.0  1219.0
# 547    9.278    5.0    30.0  ...  4526.0   8491.0  13017.0  1646.0  1080.0
# 3685  12.336    1.0    22.0  ...  4375.0   9278.0  13653.0  3119.0   771.0
# 1064   6.940   82.0   355.0  ...  4329.0   7625.0  11954.0  1600.0   611.0
# 639    8.524  538.0  2020.0  ...  4260.0   8286.0  12546.0  4215.0  1648.0
# 1155  10.077    0.0     2.0  ...  4115.0   9259.0  13374.0  1316.0   523.0
# 1655   9.120   25.0   124.0  ...  4034.0   9714.0  13748.0  3058.0  2162.0
# 649    8.747   68.0   269.0  ...  3924.0   8281.0  12205.0  3217.0  1351.0
#
#          BLK     TOV      PF      PTS   Year
# 3057  1914.0  3804.0  3351.0  28492.0  41688
# 2502   879.0  2930.0  4856.0  19923.0  53897
# 3470  2361.0  3183.0  4443.0  23334.0  41727
# 547   1100.0  2784.0  4267.0  16784.0  33830
# 3685  2820.0  3491.0  4374.0  29428.0  42054
# 1064   531.0  1484.0  2843.0   6683.0  27909
# 639    888.0  3376.0  3287.0  23757.0  31880
# 1155  3492.0  2317.0  3587.0  12478.0  40011
# 1655  3830.0  3667.0  4383.0  26946.0  35883
# 649    384.0  2785.0  4421.0  12417.0  37905
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_reboteiros_ofensivos['Player'],
                    eixo_y=maiores_reboteiros_ofensivos['ORB'],
                    titulo='Maiores reboteiros ofensivos da história',
                    y_label='Rebotes ofensivos', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# O três vezes MVP da NBA e uma vez campeão, o grande pivô Moses Malone, tendo uma diferença absurda para o segundo lugar. Para muitos, esse é um dos recordes quase impossíveis de quebrar na NBA

# %% [markdown]
# ## Rebotes defensivos

# %%
maiores_reboteiros_defensivos = jogadores.sort_values(by=['DRB'], axis=0, ascending=False)
maiores_reboteiros_defensivos.head(10)
# Out:
#                     Player  Age       G      GS       MP       FG      FGA  \
# 2474        Kevin Garnett*  685  1509.0  1472.0  51370.0  10648.0  21448.0
# 2381          Karl Malone*  589  1476.0  1471.0  54852.0  13528.0  26210.0
# 3895           Tim Duncan*  570  1392.0  1389.0  47368.0  10285.0  20334.0
# 3470        Robert Parish*  693  1611.0  1134.0  45704.0   9614.0  17914.0
# 3057         Moses Malone*  612  1411.0   784.0  47577.0   9824.0  20035.0
# 1163         Dirk Nowitzki  630  1522.0  1460.0  51368.0  11169.0  23734.0
# 1265         Dwight Howard  424  1113.0  1045.0  37290.0   6739.0  11494.0
# 1655      Hakeem Olajuwon*  549  1238.0  1186.0  44222.0  10749.0  20991.0
# 2379  Kareem Abdul-Jabbar*  630  1560.0   625.0  57446.0  15837.0  28307.0
# 3685     Shaquille O'Neal*  621  1268.0  1258.0  43666.0  11661.0  20015.0
#
#          FG%      3P     3PA  ...     ORB      DRB      TRB     AST     STL  \
# 2474  11.422   175.0   639.0  ...  3257.0  11716.0  14973.0  5522.0  1905.0
# 2381   9.745    85.0   310.0  ...  3562.0  11406.0  14968.0  5248.0  2085.0
# 3895   9.584    30.0   168.0  ...  3859.0  11232.0  15091.0  4225.0  1025.0
# 3470  11.124     0.0     6.0  ...  4598.0  10117.0  14715.0  2180.0  1219.0
# 3057   9.428     8.0    80.0  ...  7168.0  10116.0  17284.0  1885.0  1156.0
# 1163   9.723  1982.0  5210.0  ...  1468.0  10021.0  11489.0  3651.0  1210.0
# 1265   9.525     9.0    68.0  ...  3843.0   9848.0  13691.0  1580.0  1017.0
# 1655   9.120    25.0   124.0  ...  4034.0   9714.0  13748.0  3058.0  2162.0
# 2379  11.167     1.0    18.0  ...  2975.0   9394.0  17440.0  5660.0  1160.0
# 3685  12.336     1.0    22.0  ...  4375.0   9278.0  13653.0  3119.0   771.0
#
#          BLK     TOV      PF      PTS   Year
# 2474  2054.0  3225.0  3670.0  26394.0  46156
# 2381  1145.0  4524.0  4578.0  36928.0  37905
# 3895  3020.0  3381.0  3304.0  26496.0  38133
# 3470  2361.0  3183.0  4443.0  23334.0  41727
# 3057  1914.0  3804.0  3351.0  28492.0  41688
# 1163  1281.0  2494.0  3601.0  31560.0  42189
# 1265  2130.0  3143.0  3597.0  18631.0  32200
# 1655  3830.0  3667.0  4383.0  26946.0  35883
# 2379  3189.0  2527.0  4657.0  38387.0  39590
# 3685  2820.0  3491.0  4374.0  29428.0  42054
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_reboteiros_defensivos['Player'],
                    eixo_y=maiores_reboteiros_defensivos['DRB'],
                    titulo='Maiores reboteiros defensivos da história',
                    y_label='Rebotes defensivos', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# O uma vez campeão e uma vez MVP da temporada regular Kevin Garnett é o líder nesse quesito. Com uma estatura de 2,11m era difícil competir com ele nos rebotes defensivos.

# %% [markdown]
# ## Rebotes totais

# %%
maiores_reboteiros_totais = jogadores.sort_values(by=['TRB'], axis=0, ascending=False)
maiores_reboteiros_totais.head(10)
# Out:
#                     Player  Age       G      GS       MP       FG      FGA  \
# 4215     Wilt Chamberlain*  469  1118.0     0.0  51160.0  13744.0  25580.0
# 327          Bill Russell*  364   963.0     0.0  40726.0   5687.0  12930.0
# 2379  Kareem Abdul-Jabbar*  630  1560.0   625.0  57446.0  15837.0  28307.0
# 4125         Walt Bellamy*  569  1290.0     0.0  47479.0   9523.0  18487.0
# 3057         Moses Malone*  612  1411.0   784.0  47577.0   9824.0  20035.0
# 1358          Elvin Hayes*  488  1303.0   129.0  50000.0  10976.0  24272.0
# 3895           Tim Duncan*  570  1392.0  1389.0  47368.0  10285.0  20334.0
# 2474        Kevin Garnett*  685  1509.0  1472.0  51370.0  10648.0  21448.0
# 2381          Karl Malone*  589  1476.0  1471.0  54852.0  13528.0  26210.0
# 3083        Nate Thurmond*  467  1042.0     0.0  37274.0   5663.0  13442.0
#
#          FG%     3P    3PA  ...     ORB      DRB      TRB     AST     STL  \
# 4215   8.955    0.0    0.0  ...     0.0      0.0  25597.0  4893.0     0.0
# 327    5.706    0.0    0.0  ...     0.0      0.0  21620.0  4100.0     0.0
# 2379  11.167    1.0   18.0  ...  2975.0   9394.0  17440.0  5660.0  1160.0
# 4125  10.719    0.0    0.0  ...   264.0    481.0  17303.0  3098.0    52.0
# 3057   9.428    8.0   80.0  ...  7168.0  10116.0  17284.0  1885.0  1156.0
# 1358   7.239    5.0   34.0  ...  2778.0   6973.0  16279.0  2398.0   864.0
# 3895   9.584   30.0  168.0  ...  3859.0  11232.0  15091.0  4225.0  1025.0
# 2474  11.422  175.0  639.0  ...  3257.0  11716.0  14973.0  5522.0  1905.0
# 2381   9.745   85.0  310.0  ...  3562.0  11406.0  14968.0  5248.0  2085.0
# 3083   6.713    0.0    0.0  ...   859.0   2127.0  14879.0  2669.0   147.0
#
#          BLK     TOV      PF      PTS   Year
# 4215     0.0     0.0  2221.0  33953.0  31461
# 327      0.0     0.0  2592.0  14522.0  25519
# 2379  3189.0  2527.0  4657.0  38387.0  39590
# 4125    48.0     0.0  4410.0  25205.0  39369
# 3057  1914.0  3804.0  3351.0  28492.0  41688
# 1358  1771.0  1358.0  4193.0  27313.0  31624
# 3895  3020.0  3381.0  3304.0  26496.0  38133
# 2474  2054.0  3225.0  3670.0  26394.0  46156
# 2381  1145.0  4524.0  4578.0  36928.0  37905
# 3083   651.0     0.0  2784.0  14783.0  31539
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_reboteiros_totais['Player'],
                    eixo_y=maiores_reboteiros_totais['TRB'],
                    titulo='Maiores reboteiros totais da história',
                    y_label='Rebotes totais', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Aqui devemos fazer uma consideração, pois tanto Wilt Chamberlain e Bill Russel não tiveram seus dados contabilizados de rebotes ofensivos nem defensivos, pois na época deles não havia essa divisão. Wilt Chamberlain é um dos maiores de todos os tempos. 2 vezes campeão da NBA e 4 vezes MVP da temporada regular, esse pivô detém até hoje o recorde de pontos em uma única partida, tendo feito 100 pontos.

# %% [markdown]
# ## Bloqueio

# %%
maiores_bloqueadores = jogadores.sort_values(by=['BLK'], axis=0, ascending=False)
maiores_bloqueadores.head(10)
# Out:
#                     Player  Age       G      GS       MP       FG      FGA  \
# 1655      Hakeem Olajuwon*  549  1238.0  1186.0  44222.0  10749.0  20991.0
# 1155      Dikembe Mutombo*  671  1271.0  1072.0  39382.0   4438.0   8601.0
# 2379  Kareem Abdul-Jabbar*  630  1560.0   625.0  57446.0  15837.0  28307.0
# 2797            Mark Eaton  341   875.0   815.0  25169.0   2072.0   4526.0
# 3895           Tim Duncan*  570  1392.0  1389.0  47368.0  10285.0  20334.0
# 1004       David Robinson*  427   987.0   985.0  34271.0   7365.0  14221.0
# 3206        Patrick Ewing*  527  1183.0  1122.0  40594.0   9702.0  19241.0
# 3685     Shaquille O'Neal*  621  1268.0  1258.0  43666.0  11661.0  20015.0
# 3691         Shawn Bradley  412   984.0   622.0  24148.0   3506.0   7713.0
# 3879          Theo Ratliff  720  1052.0   721.0  26855.0   2890.0   5834.0
#
#          FG%    3P    3PA  ...     ORB      DRB      TRB     AST     STL  \
# 1655   9.120  25.0  124.0  ...  4034.0   9714.0  13748.0  3058.0  2162.0
# 1155  10.077   0.0    2.0  ...  4115.0   9259.0  13374.0  1316.0   523.0
# 2379  11.167   1.0   18.0  ...  2975.0   9394.0  17440.0  5660.0  1160.0
# 2797   5.177   0.0    2.0  ...  1857.0   5082.0   6939.0   840.0   368.0
# 3895   9.584  30.0  168.0  ...  3859.0  11232.0  15091.0  4225.0  1025.0
# 1004   7.182  25.0  100.0  ...  3083.0   7414.0  10497.0  2441.0  1388.0
# 3206   8.421  19.0  125.0  ...  2752.0   8855.0  11607.0  2215.0  1136.0
# 3685  12.336   1.0   22.0  ...  4375.0   9278.0  13653.0  3119.0   771.0
# 3691   7.350   5.0   51.0  ...  2185.0   4332.0   6517.0   688.0   621.0
# 3879  11.409   0.0    3.0  ...  2050.0   3953.0   6003.0   632.0   516.0
#
#          BLK     TOV      PF      PTS   Year
# 1655  3830.0  3667.0  4383.0  26946.0  35883
# 1155  3492.0  2317.0  3587.0  12478.0  40011
# 2379  3189.0  2527.0  4657.0  38387.0  39590
# 2797  3064.0  1293.0  2955.0   5216.0  21868
# 3895  3020.0  3381.0  3304.0  26496.0  38133
# 1004  2954.0  2417.0  2835.0  20790.0  27951
# 3206  2894.0  3537.0  4034.0  24815.0  33898
# 3685  2820.0  3491.0  4374.0  29428.0  42054
# 3691  2655.0  1372.0  3090.0   8657.0  31980
# 3879  2631.0  1299.0  3026.0   7579.0  48096
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_bloqueadores['Player'],
                    eixo_y=maiores_bloqueadores['BLK'],
                    titulo='Maiores jogadores bloqueadores da história',
                    y_label='Bloqueios', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# A lenda do Houston Rockets, Hakeem Olajuwon, bicampeão da NBA e uma vez MVP, é considerado um dos maiores defensores de todos os tempos. Junto com Michael Jordan e Giannis Antetokounmpo, é um dos que conseguiu ser MVP e jogador defensivo do ano na mesma temporada.

# %% [markdown]
# ## Steal (roubos de bola)

# %%
maiores_roubadores = jogadores.sort_values(by=['STL'], axis=0, ascending=False)
maiores_roubadores.head(10)
# Out:
#                Player  Age       G      GS       MP       FG      FGA    FG%  \
# 2239   John Stockton*  589  1504.0  1300.0  47764.0   7039.0  13658.0  9.737
# 1930      Jason Kidd*  684  1526.0  1475.0  54981.0   6737.0  16879.0  9.150
# 1508     Gary Payton*  578  1415.0  1313.0  50325.0   9373.0  20164.0  8.746
# 2931  Michael Jordan*  432  1072.0  1039.0  41011.0  12192.0  24537.0  7.324
# 2875  Maurice Cheeks*  501  1182.0  1040.0  37364.0   5213.0   9983.0  8.879
# 790    Clyde Drexler*  484  1162.0  1025.0  40265.0   8906.0  18911.0  7.924
# 3645  Scottie Pippen*  510  1178.0  1053.0  41069.0   7420.0  15700.0  7.850
# 115   Alvin Robertson  327   848.0   734.0  26675.0   4659.0   9784.0  5.685
# 721        Chris Paul  405  1020.0  1020.0  35558.0   6596.0  14019.0  7.031
# 101    Allen Iverson*  581  1064.0  1042.0  43303.0   9532.0  22369.0  8.674
#
#           3P     3PA  ...     ORB     DRB     TRB      AST     STL    BLK  \
# 2239   845.0  2203.0  ...   966.0  3085.0  4051.0  15806.0  3265.0  315.0
# 1930  2168.0  6178.0  ...  1926.0  7648.0  9574.0  13393.0  2944.0  496.0
# 1508  1186.0  3752.0  ...  1471.0  4132.0  5603.0   9629.0  2578.0  305.0
# 2931   581.0  1778.0  ...  1668.0  5004.0  6672.0   5633.0  2514.0  893.0
# 2875    56.0   220.0  ...   763.0  2565.0  3328.0   7845.0  2434.0  304.0
# 790    974.0  3011.0  ...  2767.0  4390.0  7157.0   6487.0  2343.0  764.0
# 3645   978.0  3002.0  ...  2068.0  5426.0  7494.0   6135.0  2307.0  947.0
# 115    276.0   922.0  ...  1728.0  2607.0  4335.0   4192.0  2267.0  341.0
# 721   1379.0  3730.0  ...   667.0  3944.0  4611.0   9653.0  2233.0  133.0
# 101   1158.0  3704.0  ...   814.0  3025.0  3839.0   6488.0  2213.0  185.0
#
#          TOV      PF      PTS   Year
# 2239  4244.0  3942.0  19711.0  37886
# 1930  4411.0  2851.0  18992.0  46086
# 1508  3217.0  3398.0  23447.0  37989
# 2931  2924.0  2783.0  32292.0  29892
# 2875  2389.0  2336.0  12984.0  33770
# 790   3163.0  3491.0  23848.0  33855
# 3645  3257.0  3329.0  18940.0  33932
# 115   2249.0  2856.0  11500.0  23883
# 721   2465.0  2500.0  18829.0  30195
# 101   3740.0  2006.0  27457.0  40101
#
# [10 rows x 28 columns]

# %%
plot_grafico_barras(eixo_x=maiores_roubadores['Player'],
                    eixo_y=maiores_roubadores['STL'],
                    titulo='Maiores roubadores de bola da história',
                    y_label='Roubos de bola', casas_decimais=0)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Novamente John Stockton aparece. Esse é considerado outros dos recordes inquebraveis, pois há um grande nível de dificuldade em roubos de bola na NBA em um número tão expressivo.

# %% [markdown]
# ## Conclusão para jogadores
#
# Podemos concluir que os dados por mais que sejam um caminho, não podem ser definição de quem é melhor que quem.
#
# Pois vamos analisar Michael Jordan, para a grande maioria o maior de todos os tempos. Ele não lidera quesito nenhum. Porém Jordan jogou apenas 15 temporadas. Kobe Bryant, por exemplo, jogou 20 e tem apenas um pouco mais de mil pontos que Jordan. Kobe e Jordan foram dois gênios, isso já demonstra o porque Jordan mesmo com menos temporada que muitos está em alta em alguns quesitos.
#
# Outro jogador que podemos falar é Earvin "Magic" Johnson Jr., que com "apenas" 13 temporadas é considerado pra muitos o maior armador de todos os tempos e um top cinco de todos os tempos.
#
# Em exemplo defensivo podemos citar Dennis Rodman, um gênio quando falamos em rebotes, porém não tem um número tão expressivo em rebotes defensivos. Mas todos sabem da qualidade dele.
#
# Esse número são apenas parâmetros para podermos analisar a NBA, ver e entender melhor.
